# %% [markdown]
# # **All Related Code To OS Library.**

# %%
import tensorflow as tf
import os

gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)

# More detailed info
for gpu in gpus:
    print(tf.config.experimental.get_device_details(gpu))
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# {'device_name': 'Quadro P1000', 'compute_capability': (6, 1)}

# %%
my_list = ["apple", "orange", "banna", "cheery"]
x = next(my_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 my_list = ["apple", "orange", "banna", "cheery"]
# ----> 3 x = next(my_list)
#
# TypeError: 'list' object is not an iterator

# %% [markdown]
# **iter(object, sentinel)**
#
# **next(iterator, default)**

# %%
x = iter(["apple", "banana", "cherry"])
print(next(x))
print(next(x))
print(next(x))
# Out:
# apple
# banana
# cherry

# %% [markdown]
# **os.walk()** Method

# %%
for (root,dirs,files) in os.walk('./../../Advance-C-Pluse-Plus/',topdown=True):
  print("Directory path: %s"%root)
  print("Directory Names: %s"%dirs)
  print("Files Names: %s"%files)
# Out:
# Directory path: ./../../Advance-C-Pluse-Plus/
# Directory Names: ['.git', 'FileSystemLib', 'PracticeQuestion', 'Smart_Pointers', 'utility_Types']
# Files Names: ['.gitignore', '10.typepunningpointercasting.cpp', '11.OverloadFuncAmbiguous.cpp', '12.SingletonOwnerShip.cpp', '13.smartptrCentralOwnerShip.cpp', '2.1.memoryModel.cpp', '3.1.IvalueReferences.cpp', '3.2.rvalueReference.cpp', '3.3.moveSemantics.cpp', '3.4..moveMethod.cpp', '7.1.structureBinding.cpp', '8.1.map.cpp', '8.2.unOrderedMap.cpp', '9.1.STL.priorityQueue.cpp', 'main.cpp', 'MixedConcepts.cpp', 'README.md', 'run.exe']
# Directory path: ./../../Advance-C-Pluse-Plus/.git
# Directory Names: ['hooks', 'info', 'logs', 'objects', 'refs']
# Files Names: ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'packed-refs']
# Directory path: ./../../Advance-C-Pluse-Plus/.git\hooks
# Directory Names: []
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
