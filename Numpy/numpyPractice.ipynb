# %%
import numpy as np
x = [1,2,3,4,5,6,7]
x= np.array(x)
x.shape
# Out:
# (7,)

# %% [markdown]
# 2D Array

# %%
y = np.array([
    [1,2,3,4,5],
    [5,6,8,9,0],
    [0,9,8,7,6]]
)



y.shape
# Out:
# (3, 5)

# %% [markdown]
# 3D Array — Stack of 2D arrays

# %%
stackarray = np.array([
    [[1,2],[2,1]],
    [[6,7],[6,5]],
])
stackarray.shape
# 2 layers × 2 rows × 2 cols
# Out:
# (2, 2, 2)

# %%
stackarray = np.array([
    [[1,2],[2,1]],
    [[6,7],[6,5]],
    [[2,4,5,8,6],[3,7,9,4,2]]
])
stackarray.shape
# 2 layers × 2 rows × 2 cols
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 stackarray = np.array([
#       2     [[1,2],[2,1]],
#       3     [[6,7],[6,5]],
#       4     [[2,4,5,8,6],[3,7,9,4,2]]
#       5 ])
#       6 stackarray.shape
#       7 # 2 layers × 2 rows × 2 cols
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (3, 2) + inhomogeneous part.

# %%
values = np.array([2, 4, 6, 8])

# %%
values = values.reshape(-1,1)

# %%
print(values)
# Out:
# [[2]
#  [4]
#  [6]
#  [8]]

# %%
values = values.reshape(-2,1)

# %%
print(values)
# Out:
# [[2]
#  [4]
#  [6]
#  [8]]

# %%
values = values.reshape(2,2)

# %%
print(values)
# Out:
# [[2 4]
#  [6 8]]

# %%
values = values.reshape(2,-1)

# %%
print(values)
# Out:
# [[2 4]
#  [6 8]]
