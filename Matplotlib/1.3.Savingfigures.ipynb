# %% [markdown]
# # **Saving Figures on PC**

# %%
# savefig("filename.extension", dpi= value, bbox_inches = "tight") 

import matplotlib.pyplot as plt

x =[1,2,3]
y = [45,65,23]

plt.plot(x,y,color="blue", marker="^")
plt.title("Simple Line plot")
plt.xlabel("X")
plt.ylabel("Y")

plt.savefig("line_plot.png", dpi=300, bbox_inches="tight") # dots per inch
plt.show()
